# %%
#Standard library
import sys
sys.path.append("..")

#Third party libraries
import pandas as pd
import matplotlib.pyplot as plt

#Local imports
from src.data.cleaner import fetch_raw_data, clean_data
from src.strategies.moving_average import generate_signal

# %%
#Fetch and clean data for Apple stock
raw_data = fetch_raw_data("AAPL", "2020-01-01", "2024-01-01")
cleaned_data = clean_data("AAPL")
